# %%
# Import dependencies
import pandas as pd
import numpy as np
import os

# %%
# Import the data into a DataFrame
vine_data = os.path.join("Tables", "vine_table.csv")
df = pd.read_csv(vine_data)
df.head(20)
# Out:
#          review_id  star_rating  helpful_votes  total_votes vine  \
# 0   R203HPW78Z7N4K            5              0            0    N
# 1   R2EAIGVLEALSP3            5              1            1    N
# 2   R1K1CD73HHLILA            5              0            0    N
# 3   R2KZBMOFRMYOPO            5              1            1    N
# 4    R6BIZOZY6UD01            5              0            0    N
# 5   R1MCXZFNF8E7Y0            1              0            0    N
# 6   R3EMB3E3ODR6BW            5              2            2    N
# 7    RJTONVTTOPJ5S            5              0            0    N
# 8   R21U5QZ2CQECUM            4              0            0    N
# 9    RL2BBC51H89DH            4              0            0    N
# 10  R3RNEPHF3WIRSZ            2              0            0    N
# 11  R38DNT9KML2PF3            5              0            0    N
# 12  R2ECMBJM8KNNC8            4              0            0    N
# 13  R2F3F92PRN9T7S            5              0            0    N
# 14  R35XNT88XVEMK6            5              1            1    N
# 15   RZRXLHQS71FUP            4              1            1    N
# 16  R3J9T4MZRAURV5            1              0            0    N
# 17  R3CLDHHI0ZSQLO            5              1            2    N
# 18   RY52KZABZK8QF            1              0            0    N
# 19  R25RXV5X29M3UC            4              0            1    N
#
#    verified_purchase
# 0                  Y
# 1                  Y
# 2                  Y
# 3                  Y
# 4                  Y
# 5                  Y
# 6                  Y
# 7                  Y
# 8                  Y
# 9                  Y
# 10                 N
# 11                 Y
# 12                 Y
# 13                 Y
# 14                 Y
# 15                 Y
# 16                 Y
# 17                 N
# 18                 Y
# 19                 Y

# %%
# Filter for reviews with at least twenty votes
popular_df = df.loc[df["total_votes"] >= 20].sort_values("review_id")
popular_df.head(20)
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 76037  R100212BMGLGI0            1             18           21    N
# 45827  R1002U1ZIY5BUT            5             44           46    N
# 44623  R100YVAS0FCQ9C            5             36           37    N
# 79894  R101W5V3SZ8LFQ            1             19           25    N
# 38378  R1028R2IEONQZL            5             10           54    N
# 47393  R10328L5NKZHYU            2             24           27    N
# 30827  R104QJT5QCZKZ8            1             38           50    N
# 94719  R1055S1327MCXB            5             45           48    N
# 73860  R1057TGFKBGGHS            5             23           23    N
# 93275  R1058IT10ZEUI7            5             69           72    N
# 89325  R1058JBPKY772B            1             22           25    N
# 31542   R105NDFWRPN3K            1             18           22    N
# 49398  R1077ZHZYCVQT4            1             20           21    N
# 56284  R107XXOIA9Z511            1             59           66    N
# 91002  R1088L6HZNOJVH            3             21           21    N
# 89698  R108TVP7OEWHEU            5             51           57    N
# 95042   R10AC3ZQU61XJ            1             43           45    N
# 75242  R10AQF5IMI561T            4             55           58    N
# 63186  R10COZGWBCI49Y            5             23           24    N
# 88314  R10D2CSPGM1R5V            4             24           24    N
#
#       verified_purchase
# 76037                 N
# 45827                 N
# 44623                 N
# 79894                 Y
# 38378                 N
# 47393                 Y
# 30827                 N
# 94719                 N
# 73860                 N
# 93275                 N
# 89325                 N
# 31542                 N
# 49398                 N
# 56284                 N
# 91002                 Y
# 89698                 N
# 95042                 N
# 75242                 N
# 63186                 Y
# 88314                 N

# %%
# Filter for reviews where at least half of the votes mark them as helpful
helpful_df = popular_df.loc[(popular_df["helpful_votes"] / popular_df["total_votes"]) >= 0.5].sort_values("review_id")
helpful_df.head(20)
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 76037  R100212BMGLGI0            1             18           21    N
# 45827  R1002U1ZIY5BUT            5             44           46    N
# 44623  R100YVAS0FCQ9C            5             36           37    N
# 79894  R101W5V3SZ8LFQ            1             19           25    N
# 47393  R10328L5NKZHYU            2             24           27    N
# 30827  R104QJT5QCZKZ8            1             38           50    N
# 94719  R1055S1327MCXB            5             45           48    N
# 73860  R1057TGFKBGGHS            5             23           23    N
# 93275  R1058IT10ZEUI7            5             69           72    N
# 89325  R1058JBPKY772B            1             22           25    N
# 31542   R105NDFWRPN3K            1             18           22    N
# 49398  R1077ZHZYCVQT4            1             20           21    N
# 56284  R107XXOIA9Z511            1             59           66    N
# 91002  R1088L6HZNOJVH            3             21           21    N
# 89698  R108TVP7OEWHEU            5             51           57    N
# 95042   R10AC3ZQU61XJ            1             43           45    N
# 75242  R10AQF5IMI561T            4             55           58    N
# 63186  R10COZGWBCI49Y            5             23           24    N
# 88314  R10D2CSPGM1R5V            4             24           24    N
# 84935  R10DCO7TPH0RWP            5             74           76    N
#
#       verified_purchase
# 76037                 N
# 45827                 N
# 44623                 N
# 79894                 Y
# 47393                 Y
# 30827                 N
# 94719                 N
# 73860                 N
# 93275                 N
# 89325                 N
# 31542                 N
# 49398                 N
# 56284                 N
# 91002                 Y
# 89698                 N
# 95042                 N
# 75242                 N
# 63186                 Y
# 88314                 N
# 84935                 Y

# %%
# Separate the results between Vine (paid) and non-Vine (unpaid)
vine_df = helpful_df.loc[helpful_df["vine"] == "Y"].sort_values("review_id")
vine_df.head(20)
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 60213  R15NQCQUNOSI4U            4             19           22    Y
# 84147  R15VXK8I0FPU0A            4             22           23    Y
# 85877  R19OUHMKNXU3DC            4             76           78    Y
# 62875  R1B3OGO36CJKDA            5             15           20    Y
# 86005  R1CXC7HG447Y0A            4             65           69    Y
# 26403  R1IDQ0G1S7J9TN            5            178          196    Y
# 36014  R1L2R8OHO171YG            5             66           68    Y
# 83514  R1SYUVX7GZZ469            4             46           51    Y
# 10115  R20O97P5V9CZ21            3             21           27    Y
# 83368  R214D7Q3CO5W5J            5             51           52    Y
# 83118  R2ACH3HF5VUWGD            4             76           78    Y
# 27720  R2K45IY0NO70ZI            5            116          122    Y
# 65380  R2SIOD5SIH2LJN            4             25           31    Y
# 61453  R2SQ2O06PRCM9D            5             28           31    Y
# 83464  R2X8VIUPVX3WP2            5             52           57    Y
# 85757  R34C4BLRJPH3TL            5             48           53    Y
# 60535  R37J6VNSC5TZVS            4             19           22    Y
# 87061  R3AMGG11RIXJRR            5             24           28    Y
# 83793  R3BQS6JYP129DV            2             19           20    Y
# 61430  R3F1V21FOEIEKN            4             30           33    Y
#
#       verified_purchase
# 60213                 N
# 84147                 N
# 85877                 N
# 62875                 Y
# 86005                 N
# 26403                 N
# 36014                 N
# 83514                 N
# 10115                 N
# 83368                 N
# 83118                 N
# 27720                 N
# 65380                 N
# 61453                 N
# 83464                 N
# 85757                 N
# 60535                 N
# 87061                 N
# 83793                 N
# 61430                 N

# %%
nonvine_df = helpful_df.loc[helpful_df["vine"] == "N"].sort_values("review_id")
nonvine_df.head(20)
# Out:
#             review_id  star_rating  helpful_votes  total_votes vine  \
# 76037  R100212BMGLGI0            1             18           21    N
# 45827  R1002U1ZIY5BUT            5             44           46    N
# 44623  R100YVAS0FCQ9C            5             36           37    N
# 79894  R101W5V3SZ8LFQ            1             19           25    N
# 47393  R10328L5NKZHYU            2             24           27    N
# 30827  R104QJT5QCZKZ8            1             38           50    N
# 94719  R1055S1327MCXB            5             45           48    N
# 73860  R1057TGFKBGGHS            5             23           23    N
# 93275  R1058IT10ZEUI7            5             69           72    N
# 89325  R1058JBPKY772B            1             22           25    N
# 31542   R105NDFWRPN3K            1             18           22    N
# 49398  R1077ZHZYCVQT4            1             20           21    N
# 56284  R107XXOIA9Z511            1             59           66    N
# 91002  R1088L6HZNOJVH            3             21           21    N
# 89698  R108TVP7OEWHEU            5             51           57    N
# 95042   R10AC3ZQU61XJ            1             43           45    N
# 75242  R10AQF5IMI561T            4             55           58    N
# 63186  R10COZGWBCI49Y            5             23           24    N
# 88314  R10D2CSPGM1R5V            4             24           24    N
# 84935  R10DCO7TPH0RWP            5             74           76    N
#
#       verified_purchase
# 76037                 N
# 45827                 N
# 44623                 N
# 79894                 Y
# 47393                 Y
# 30827                 N
# 94719                 N
# 73860                 N
# 93275                 N
# 89325                 N
# 31542                 N
# 49398                 N
# 56284                 N
# 91002                 Y
# 89698                 N
# 95042                 N
# 75242                 N
# 63186                 Y
# 88314                 N
# 84935                 Y

# %%
# Count up the reviews
total_count = helpful_df["review_id"].count()
vine_count = vine_df["review_id"].count()
nonvine_count = nonvine_df["review_id"].count()
five_count = helpful_df["review_id"].loc[helpful_df["star_rating"] == 5].count()
five_vine = vine_df["review_id"].loc[vine_df["star_rating"] == 5].count()
five_nonvine = nonvine_df["review_id"].loc[nonvine_df["star_rating"] == 5].count()

# %%
# Calculate the percentages
star_percent = five_count / total_count * 100
vine_percent = five_vine / vine_count * 100
nonvine_percent = five_nonvine / nonvine_count * 100

# %%
# Print the results
print(f"There are {total_count:,} reviews that are considered helpful.")
print(f"{vine_count:,} reviews come from Vine members; and {nonvine_count:,} reviews come from non-Vine members.")
print(f"{five_count:,} are 5-Star reviews, comprising {star_percent:.3f}% of all the helpful reviews.")
print(f"{five_vine:,} Vine reviews have a 5-Star rating, forming {vine_percent:.3f}% of the Vine reviews.")
print(f"{five_nonvine:,} non-Vine reviews have a 5-Star rating, forming {nonvine_percent:.3f}% of the non-Vine reviews.")
# Out:
# There are 4,992 reviews that are considered helpful.
# 35 reviews come from Vine members; and 4,957 reviews come from non-Vine members.
# 1,981 are 5-Star reviews, comprising 39.683% of all the helpful reviews.
# 18 Vine reviews have a 5-Star rating, forming 51.429% of the Vine reviews.
# 1,963 non-Vine reviews have a 5-Star rating, forming 39.601% of the non-Vine reviews.
